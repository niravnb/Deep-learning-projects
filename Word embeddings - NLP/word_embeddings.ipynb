# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (4.2.6)

# %%
import bs4 as bs
import urllib.request
import re
import nltk

scrapped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scrapped_data .read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Cleaing the text
processed_article = article_text.lower()
processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )
processed_article = re.sub(r'\s+', ' ', processed_article)

# Preparing the dataset
all_sentences = nltk.sent_tokenize(processed_article)

all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# Removing Stop Words
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in stopwords.words('english')]

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec(all_words, min_count=2)

# %%
vocabulary = word2vec.wv.vocab
print(vocabulary)
# Out:
# {'computer': <gensim.models.keyedvectors.Vocab object at 0x7fb5bb7dce48>, 'science': <gensim.models.keyedvectors.Vocab object at 0x7fb5ea134668>, 'artificial': <gensim.models.keyedvectors.Vocab object at 0x7fb5ea13cb70>, 'intelligence': <gensim.models.keyedvectors.Vocab object at 0x7fb5bb7de9e8>, 'ai': <gensim.models.keyedvectors.Vocab object at 0x7fb5bb06a128>, 'sometimes': <gensim.models.keyedvectors.Vocab object at 0x7fb5ba7059e8>, 'called': <gensim.models.keyedvectors.Vocab object at 0x7fb5ba705cf8>, 'machine': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9e0beb8>, 'demonstrated': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db69e8>, 'machines': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6a20>, 'contrast': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6a58>, 'natural': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6a90>, 'displayed': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6ac8>, 'humans': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6b00>, 'leading': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6b38>, 'field': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6b70>, 'study': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6ba8>, 'intelligent': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6be0>, 'agents': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6c18>, 'device': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6c50>, 'perceives': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6c88>, 'environment': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6cc0>, 'takes': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6cf8>, 'actions': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6d30>, 'maximize': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6d68>, 'chance': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6da0>, 'successfully': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6dd8>, 'achieving': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6e10>, 'goals': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6e48>, 'term': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6e80>, 'often': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6eb8>, 'used': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6ef0>, 'describe': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6f28>, 'computers': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6f60>, 'mimic': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6f98>, 'cognitive': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9db6fd0>, 'functions': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6048>, 'human': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6080>, 'mind': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc60b8>, 'learning': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc60f0>, 'problem': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6128>, 'solving': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6160>, 'become': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6198>, 'increasingly': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc61d0>, 'capable': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6208>, 'tasks': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6240>, 'considered': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6278>, 'require': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc62b0>, 'definition': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc62e8>, 'phenomenon': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6320>, 'known': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6358>, 'effect': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6390>, 'done': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc63c8>, 'yet': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6400>, 'instance': <gensim.models.keyedvectors.Vocab object at 0x7fb5b9dc6438>, 'character': <gensim.mod ...

# %%
v1 = word2vec.wv['artificial']
v1.shape
# Out:
# (100,)

# %%
sim_words = word2vec.wv.most_similar('intelligence')
sim_words
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('ai', 0.8242389559745789),
#  ('many', 0.7887574434280396),
#  ('data', 0.7556469440460205),
#  ('research', 0.7399556636810303),
#  ('machine', 0.7369707822799683),
#  ('human', 0.7326751947402954),
#  ('artificial', 0.7322235107421875),
#  ('learning', 0.728238582611084),
#  ('could', 0.6924635171890259),
#  ('problem', 0.6917307376861572)]
